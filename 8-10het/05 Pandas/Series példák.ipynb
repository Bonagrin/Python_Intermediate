# %%
import pandas as pd
print(pd.__version__)
# Out:
# 1.4.2

# %%
pd.Series([3, 2, 5])
# Out:
# 0    3
# 1    2
# 2    5
# dtype: int64

# %%
pd.Series(data=[3, 2, 5], index=['alma', 'banán', 'narancs'])
# Out:
# alma       3
# banán      2
# narancs    5
# dtype: int64

# %%
import numpy as np
pd.Series(np.arange(10, 40, 10))
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int32

# %%
pd.Series(data=[3, 2, 5], index=['alma', 'banán', 'narancs']) + \
pd.Series(data=[2, 3, 4], index=['alma', 'banán', 'narancs'])
# Out:
# alma       5
# banán      5
# narancs    9
# dtype: int64

# %%
pd.Series(data=[3, 2, 5], index=['alma', 'banán', 'narancs']) + \
pd.Series(data=[2, 3, 4], index=['alma', 'meggy', 'banán'])
# Out:
# alma       5.0
# banán      6.0
# meggy      NaN
# narancs    NaN
# dtype: float64
